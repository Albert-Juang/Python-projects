# %%
import pandas as pd

# %%
df=pd.read_csv('draft-data-20-years.csv')

# %%
UNC = df.loc[df['College']=="UNC"]

# %%
UNC = df.loc[0]
df.head()
# Out:
#    Unnamed: 0  Rk  Pk   Tm              Player       College   Yrs       G  \
# 0           1   1   1  BRK     Derrick Coleman      Syracuse  15.0   781.0
# 1           2   2   2  OKC         Gary Payton  Oregon State  17.0  1335.0
# 2           3   3   3  DEN  Mahmoud Abdul-Rauf           LSU   9.0   586.0
# 3           4   4   4  ORL        Dennis Scott  Georgia Tech  10.0   629.0
# 4           5   5   5  CHA        Kendall Gill      Illinois  15.0   966.0
#
#      TOTMP   TOTPTS  ...  WS/48  BPM  VORP  DraftYr   MPG   PPG  RPG  APG  \
# 0  25903.0  12884.0  ...  0.119  1.4  22.3     1990  33.2  16.5  9.3  2.5
# 1  47117.0  21813.0  ...  0.148  3.3  62.5     1990  35.3  16.3  3.9  6.7
# 2  15628.0   8553.0  ...  0.077 -0.8   4.5     1990  26.7  14.6  1.9  3.5
# 3  17983.0   8094.0  ...  0.089  0.2   9.9     1990  28.6  12.9  2.8  2.1
# 4  29481.0  12914.0  ...  0.078  0.1  15.8     1990  30.5  13.4  4.1  3.0
#
#                                            playerurl  DraftYear
# ...

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                                    1
# Rk                                                            1
# Pk                                                            1
# Tm                                                          BRK
# Player                                          Derrick Coleman
# College                                                Syracuse
# Yrs                                                        15.0
# G                                                         781.0
# TOTMP                                                   25903.0
# TOTPTS                                                  12884.0
# TOTTRB                                                   7232.0
# TOTAST                                                   1985.0
# FG%                                                       0.447
# 3P%                                                       0.295
# FT%                                                       0.769
# ...

# %%
df.loc[df['Tm']="ORL"]
# Out:
#   File "/var/folders/jy/gdpkm29d0nj8bcmt521pq7yr0000gn/T/ipykernel_1338/2558015783.py", line 1
#     df.loc[df['Tm']="ORL"]
#                    ^
# SyntaxError: invalid syntax

# %%
import re
df.loc[df['Player'].str.contains('man',regex=True)]
# Out:
#       Unnamed: 0  Rk  Pk   Tm                 Player  \
# 0              1   1   1  BRK        Derrick Coleman
# 441          442  56  56  UTA           Nate Erdmann
# 628          629  12  12  OKC    Vladimir Radmanović
# 662          663  47  47  DEN          Ousmane Cisse
# 736          737   6   6  LAC            Chris Kaman
# 770          771  40  40  GSW      Derrick Zimmerman
# 819          820  31  31  CHI         Jackson Vroman
# 927          928  20  20  NYK        Renaldo Balkman
# 1125        1126  38  38  POR           Jon Brockman
# 1143        1144  56  56  DAL           Ahman Nivins
# 1179        1180  32  32  MIA         Dexter Pittman
# 1182        1183  35  35  WAS        Nemanja Bjelica
# 1224        1225  17  17  NYK          Iman Shumpert
# 1324        1325  57  57  BRK          İlkan Karaman
# 1357        1358  30  30  PHO        Nemanja Nedović
# 1441        1442  54  54  PHI       Nemanja Dangubić
# 1454        1455   7   7  DEN        Emmanuel Mudiay
# ...
